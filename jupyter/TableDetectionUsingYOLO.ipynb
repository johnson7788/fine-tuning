# %% [markdown]
# # Table detection using YOLO
#
# This notebook can be employed to detect tables in images using a YOLO detection model.
#
# We need to download some files that are required to run the YOLO model by executing the following cell. We also download some images for testing.

# %%
# !pip install imutils
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/yolo/predict.py -O predict.py
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/yolo/tablasFinaltest416320.cfg -O tablasFinaltest416320.cfg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/yolo/vocTablas.names -O vocTablas.names
# !wget https://www.dropbox.com/s/jbgosn1t83h1bqi/tablasFinaltrain_10000.weights?dl=0 -O tablasFinaltrain_10000.weights
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100058.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100171.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100183.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100341.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100491.jpg
# Out:
# Requirement already satisfied: imutils in /usr/local/lib/python3.6/dist-packages (0.5.3)
# --2019-11-26 18:21:41--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/yolo/predict.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6219 (6.1K) [text/plain]
# Saving to: ‘predict.py’
#
# predict.py          100%[===================>]   6.07K  --.-KB/s    in 0s
#
# 2019-11-26 18:21:41 (79.4 MB/s) - ‘predict.py’ saved [6219/6219]
#
# --2019-11-26 18:21:44--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/yolo/tablasFinaltest416320.cfg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8334 (8.1K) [text/plain]
# Saving to: ‘tablasFinaltest416320.cfg’
#
# tablasFinaltest4163 100%[===================>]   8.14K  --.-KB/s    in 0s
#
# 2019-11-26 18:21:44 (119 MB/s) - ‘tablasFinaltest416320.cfg’ saved [8334/8334]
#
# --2019-11-26 18:21:46--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/yolo/vocTablas.names
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6 [text/plain]
# Saving to: ‘vocTablas.names’
#
# vocTablas.names     100%[===================>]       6  --.-KB/s    in 0s
#
# 2019-11-26 18:21:46 (1.29 MB/s) - ‘vocTablas.names’ saved [6/6]
#
# --2019-11-26 18:21:47--  https://www.dropbox.com/s/jbgosn1t83h1bqi/tablasFinaltrain_10000.weights?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/jbgosn1t83h1bqi/tablasFinaltrain_10000.weights [following]
# --2019-11-26 18:21:47--  https://www.dropbox.com/s/raw/jbgosn1t83h1bqi/tablasFinaltrain_10000.weights
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com/cd/0/inline/AtHBTd_JgOjxDZwXq-u6v--M64VC4qZ6MquHU6NuVkJHbxlkFvVZupLYuxGZlsVPWleZooC6vvw8tuaeA0cB5NodtzJNxzzWKq00aAVaESt2xesjGnh2uW3m2xqyhRSgi9E/file# [following]
# --2019-11-26 18:21:47--  https://ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com/cd/0/inline/AtHBTd_JgOjxDZwXq-u6v--M64VC4qZ6MquHU6NuVkJHbxlkFvVZupLYuxGZlsVPWleZooC6vvw8tuaeA0cB5NodtzJNxzzWKq00aAVaESt2xesjGnh2uW3m2xqyhRSgi9E/file
# Resolving ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com (ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com (ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/AtEfeON7FoxBRYu1LqbwLIfCB23jA0ot6atYZpf_k2doVBSMiYVzgLZhauUpsViUBZr0b7z-ufj3HITJtVtlpwIKZlSXPCdesPCsIE5zVqE9tE0J1gsW1MlfUGBh_KANbGIU_AtEkJf6BFbfDYTkbgDROf5dWEDUid4IRcT3pE50YHpN4fKWkpQ6BUeuXOqnS3VM68pAzXqOnbOY3yrhpP9o1zQc8aqYCnFl6FDZo3xC-OYwHVOyyTQHzyDvdcYzEx29zWZIMXWwGMwKfD3YBOlsy-UdwJHn4M0SyUv1yjN9fvUkijViBXR2nIqUfB31xb0utGkqqw_EFe8eoCcl46rtIUkQr4UtSnXvdkvwGaSuTg/file [following]
# --2019-11-26 18:21:48--  https://ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com/cd/0/inline2/AtEfeON7FoxBRYu1LqbwLIfCB23jA0ot6atYZpf_k2doVBSMiYVzgLZhauUpsViUBZr0b7z-ufj3HITJtVtlpwIKZlSXPCdesPCsIE5zVqE9tE0J1gsW1MlfUGBh_KANbGIU_AtEkJf6BFbfDYTkbgDROf5dWEDUid4IRcT3pE50YHpN4fKWkpQ6BUeuXOqnS3VM68pAzXqOnbOY3yrhpP9o1zQc8aqYCnFl6FDZo3xC-OYwHVOyyTQHzyDvdcYzEx29zWZIMXWwGMwKfD3YBOlsy-UdwJHn4M0SyUv1yjN9fvUkijViBXR2nIqUfB31xb0utGkqqw_EFe8eoCcl46rtIUkQr4UtSnXvdkvwGaSuTg/file
# Reusing existing connection to ucbccbbe1f54270fc117330d036e.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 246305388 (235M) [application/octet-stream]
# Saving to: ‘tablasFinaltrain_10000.weights’
#
# tablasFinaltrain_10 100%[===================>] 234.89M  43.1MB/s    in 5.6s
#
# 2019-11-26 18:21:54 (42.3 MB/s) - ‘tablasFinaltrain_10000.weights’ saved [246305388/246305388]
#
# --2019-11-26 18:21:55--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100058.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126211 (123K) [image/jpeg]
# Saving to: ‘Latex_100058.jpg’
#
# Latex_100058.jpg    100%[===================>] 123.25K  --.-KB/s    in 0.03s
#
# 2019-11-26 18:21:55 (4.12 MB/s) - ‘Latex_100058.jpg’ saved [126211/126211]
#
# --2019-11-26 18:21:56--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100171.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104758 (102K) [image/jpeg]
# Saving to: ‘Latex_100171.jpg’
#
# Latex_100171.jpg    100%[===================>] 102.30K  --.-KB/s    in 0.03s
#
# 2019-11-26 18:21:56 (3.34 MB/s) - ‘Latex_100171.jpg’ saved [104758/104758]
#
# --2019-11-26 18:21:57--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100183.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87426 (85K) [image/jpeg]
# Saving to: ‘Latex_100183.jpg’
#
# Latex_100183.jpg    100%[===================>]  85.38K  --.-KB/s    in 0.02s
#
# 2019-11-26 18:21:57 (4.08 MB/s) - ‘Latex_100183.jpg’ saved [87426/87426]
#
# --2019-11-26 18:21:59--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100341.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96492 (94K) [image/jpeg]
# Saving to: ‘Latex_100341.jpg’
#
# Latex_100341.jpg    100%[===================>]  94.23K  --.-KB/s    in 0.02s
#
# 2019-11-26 18:21:59 (4.57 MB/s) - ‘Latex_100341.jpg’ saved [96492/96492]
#
# --2019-11-26 18:22:00--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100491.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101154 (99K) [image/jpeg]
# Saving to: ‘Latex_100491.jpg’
#
# Latex_100491.jpg    100%[===================>]  98.78K  --.-KB/s    in 0.03s
#
# 2019-11-26 18:22:00 (3.21 MB/s) - ‘Latex_100491.jpg’ saved [101154/101154]

# %% [markdown]
# Once the above files are downloaded, we can load the functionality to detect ablaes in the images, and some additional libraries that are necessary for uploading your images.

# %%
from predict import predict,showImage
from google.colab import files
import cv2

# %% [markdown]
# You can upload your own images by using the left side menu, and detect the tables with the following command where you can change the name of the image.

# %%
# %%time
predict("Latex_100058.jpg")
# Out:
# CPU times: user 3.13 s, sys: 234 ms, total: 3.37 s
# Wall time: 2.17 s
# [[316, 130, 250, 159]]

# %% [markdown]
# Now, we show the result inside the notebook.

# %%
image = cv2.imread('prediction.jpg')
showImage(image)

# %% [markdown]
# It is also possible to download the image from the Files menu on the left side of the browser.

# %% [markdown]
# Other examples.

# %%
predict("Latex_100171.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)

# %%
predict("Latex_100183.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)

# %%
predict("Latex_100341.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)

# %%
predict("Latex_100491.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)
